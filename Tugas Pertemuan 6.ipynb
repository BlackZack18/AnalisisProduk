# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset (products_dataset.csv)
# - Kelompok : hihau
# - Anggota : </br>
# 10122373 - Rakin Zakiy Saputra</br>
# 10122366 - Suswan Guevara Aryadhi</br>
# 10122363 - Arif Julianto</br>
# 10122383 - Mutiara Intan Suryani</br>
# 10122369 - Syahrial Usman Farahani

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana distribusi tinggi produk? Berapa rata-rata nya?  - 10122373 - Rakin Zakiy Saputra
# - Berapa kisaran berat yang paling umum? - 10122366 - Suswan Guevara Aryadhi
# - Berapa rata-rata panjang produk? - 10122363 - Arif Julianto
# - Berapakah lebar produk yang terbesar dan terkecil?  - 10122383 - Mutiara Intan Suryani
# - Seberapa efektif pemilihan nama produk berdasarkan rata-rata panjang karakternya  - 10122369 - Syahrial Usman Farahani

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df = pd.read_csv("E-Commerce Public Dataset/products_dataset.csv")
df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# ### Assessing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df.duplicated().values.any()
# Out:
# False

# %% [markdown]
# ### Cleaning Data

# %%
df.dropna(inplace=True)
df.drop('product_id', axis=1, inplace=True)
df.drop('product_photos_qty', axis=1, inplace=True)
df.isnull().sum()
# Out:
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
sns.set_palette("Pastel1")
plt.figure(figsize=(10, 6))

sns.pairplot(df)

plt.suptitle('Pair Plot Product')
plt.show()

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Membuat Tabel Tinggi Produk
height_table = df[['product_category_name', 'product_height_cm']]
height_table = height_table.rename(columns={'product_category_name': 'Nama Produk', 'product_height_cm': 'Tinggi Produk (cm)'})

# Informasi Rata-rata, nilai max, dan nilai min
average_height = df['product_height_cm'].mean()
max_height = df['product_height_cm'].max()
min_height = df['product_height_cm'].min()

# %%
# Tabel dan Informasi
display(height_table)
print(f"Rata rata tinggi produk : {average_height:.2f} cm")
print(f"Produk paling tinggi : {max_height} cm")
print(f"Produk paling pendek : {min_height} cm")
# Out:
#                              Nama Produk  Tinggi Produk (cm)
# 0                             perfumaria                10.0
# 1                                  artes                18.0
# 2                          esporte_lazer                 9.0
# 3                                  bebes                 4.0
# 4                  utilidades_domesticas                17.0
# ...                                  ...                 ...
# 32946                   moveis_decoracao                40.0
# 32947  construcao_ferramentas_iluminacao                19.0
# 32948                    cama_mesa_banho                 7.0
# 32949             informatica_acessorios                13.0
# 32950                    cama_mesa_banho                 2.0
#
# [32340 rows x 2 columns]
# Rata rata tinggi produk : 16.96 cm
# Produk paling tinggi : 105.0 cm
# Produk paling pendek : 2.0 cm

# %%
# Visualisasi distribusi tinggi produk dan informasinya
plt.figure(figsize=(8, 5))
plt.hist(df['product_height_cm'], bins=20, color='cyan', edgecolor='black')
plt.axvline(x=df['product_height_cm'].mean(), color='red', linestyle='dashed', linewidth=2, label='Rata-rata Tinggi')
plt.title('Distribusi Tinggi Produk dan Garis Referensi')
plt.xlabel('Tinggi Produk (cm)')
plt.ylabel('Frekuensi')

plt.legend()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
df['product_weight_kg'] = df['product_weight_g'] / 1000
weight_table = df[['product_category_name', 'product_weight_kg']]
weight_table = weight_table.rename(columns={'product_category_name': 'Nama Produk', 'product_weight_kg': 'Berat Produk (kg)'})
weight_table
# Out:
#                              Nama Produk  Berat Produk (kg)
# 0                             perfumaria              0.225
# 1                                  artes              1.000
# 2                          esporte_lazer              0.154
# 3                                  bebes              0.371
# 4                  utilidades_domesticas              0.625
# ...                                  ...                ...
# 32946                   moveis_decoracao             12.300
# 32947  construcao_ferramentas_iluminacao              1.700
# 32948                    cama_mesa_banho              1.400
# 32949             informatica_acessorios              0.700
# 32950                    cama_mesa_banho              2.083
#
# [32340 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['product_weight_kg'], bins=15, color='blue', edgecolor='black')
plt.title('Berat Produk')
plt.xlabel('Berat Produk (kg)')
plt.ylabel('Frekuensi')
plt.show()

# %%
print("Berat Produk Terendah : ", df['product_weight_kg'].min())
print("Berat Produk Tertinggi : ", df['product_weight_kg'].max())
print("Berat Produk Tertinggi : ", df['product_weight_kg'].mean())
# Out:
# Berat Produk Terendah :  0.0
# Berat Produk Tertinggi :  40.425
# Berat Produk Tertinggi :  2.276956586270872

# %% [markdown]
# ### Pertanyaan 3:

# %%
length_table = df[['product_category_name', 'product_length_cm']]
length_table = length_table.rename(columns={'product_category_name': 'Nama Produk', 'product_length_cm': 'Panjang Produk (cm)'})
length_table
# Out:
#                              Nama Produk  Panjang Produk (cm)
# 0                             perfumaria                 16.0
# 1                                  artes                 30.0
# 2                          esporte_lazer                 18.0
# 3                                  bebes                 26.0
# 4                  utilidades_domesticas                 20.0
# ...                                  ...                  ...
# 32946                   moveis_decoracao                 40.0
# 32947  construcao_ferramentas_iluminacao                 16.0
# 32948                    cama_mesa_banho                 27.0
# 32949             informatica_acessorios                 31.0
# 32950                    cama_mesa_banho                 12.0
#
# [32340 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['product_length_cm'], bins=20, color='yellow', edgecolor='black')
plt.title('Panjang Produk')
plt.xlabel('Panjang Produk (cm)')
plt.ylabel('Frekuensi')
plt.show()

# %%
print("Panjang Produk Terendah : ", df['product_length_cm'].min())
print("Panjang Produk Tertinggi : ", df['product_length_cm'].max())
print("Panjang Produk Rata-rata : ", df['product_length_cm'].mean())
# Out:
# Panjang Produk Terendah :  7.0
# Panjang Produk Tertinggi :  105.0
# Panjang Produk Rata-rata :  30.854545454545455

# %% [markdown]
# ### Pertanyaan 4:

# %%
width_table = df[['product_category_name', 'product_width_cm']]
width_table = width_table.rename(columns={'product_category_name': 'Nama Produk', 'product_width_cm': 'Lebar Produk (cm)'})
width_table
# Out:
#                              Nama Produk  Lebar Produk (cm)
# 0                             perfumaria               14.0
# 1                                  artes               20.0
# 2                          esporte_lazer               15.0
# 3                                  bebes               26.0
# 4                  utilidades_domesticas               13.0
# ...                                  ...                ...
# 32946                   moveis_decoracao               40.0
# 32947  construcao_ferramentas_iluminacao               16.0
# 32948                    cama_mesa_banho               27.0
# 32949             informatica_acessorios               20.0
# 32950                    cama_mesa_banho                7.0
#
# [32340 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['product_width_cm'], bins=20, color='pink', edgecolor='black')
plt.title('Diagram Lebar Produk')
plt.xlabel('Lebar Produk (cm)')
plt.ylabel('Frekuensi')
plt.show()

# %%
print("Produk Paling Lebar    : ", df['product_category_name'].max(), "->", df['product_width_cm'].max(), "cm")
print("Produk Paling Kecil    : ", df['product_category_name'].min(), "->", df['product_width_cm'].min(), "cm")  
print("Lebar Produk Rata-Rata : ", df['product_width_cm'].mean(), "cm")
# Out:
# Produk Paling Lebar    :  utilidades_domesticas -> 118.0 cm
# Produk Paling Kecil    :  agro_industria_e_comercio -> 6.0 cm
# Lebar Produk Rata-Rata :  23.208596165739024 cm

# %% [markdown]
# ### Pertanyaan 5:

# %%
name_table = df[['product_category_name', 'product_name_lenght']]
name_table = name_table.rename(columns={'product_category_name': 'Nama Produk', 'product_name_lenght': 'Panjang Karakter'})

average_name = df['product_name_lenght'].mean()
max_name = df['product_name_lenght'].max()
min_name = df['product_name_lenght'].min()

display(name_table)
print("Produk Dengan Nama Paling Panjang  : ", df['product_name_lenght'].max())
print("Produk Dengan Nama Paling Pendek   : ", df['product_name_lenght'].min())  
print("Panjang Karakter Rata-Rata : ", df['product_name_lenght'].mean(),)
# Out:
#                              Nama Produk  Panjang Karakter
# 0                             perfumaria              40.0
# 1                                  artes              44.0
# 2                          esporte_lazer              46.0
# 3                                  bebes              27.0
# 4                  utilidades_domesticas              37.0
# ...                                  ...               ...
# 32946                   moveis_decoracao              45.0
# 32947  construcao_ferramentas_iluminacao              41.0
# 32948                    cama_mesa_banho              50.0
# 32949             informatica_acessorios              60.0
# 32950                    cama_mesa_banho              58.0
#
# [32340 rows x 2 columns]
# Produk Dengan Nama Paling Panjang  :  76.0
# Produk Dengan Nama Paling Pendek   :  5.0
# Panjang Karakter Rata-Rata :  48.47659245516388

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['product_name_lenght'], bins=20, color='blue', edgecolor='black')
plt.title('Grafik Panjang Karakter')
plt.xlabel('Jumlah Karakter')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan data di atas, kita bisa mengetahui penggunaan jumlah karakter dari yang paling pendek hingga pailing panjang dalam penamaan prodak.
# menurut data di atas,50 samapi 60 karakter adalah kisaran paling banyak dalam penamaan prodak,dari sini kita bisa pempertimbangkan jumlah karakter dalam
# penamaan prodak kita jika ingin memulai bisnis.

# %% [markdown]
# <h1>Conclution</h1>
#
# - Conclution pertanyaan 1 :  </br>
#  Distribusi tinggi produk cenderung beragam, dengan titik-titik data tersebar di berbagai tinggi. Rata-rata tinggi produk berada pada nilai tertentu (misalnya, pada garis merah dalam visualisasi).
# - Conclution pertanyaan 2 :</br>
#   jika dilihat dari tabel maka ada lebih dari 25000 barang yang memiliki berat dibawah 3kg. Dengan berat terkecil : 0 kg, tertinggi : 40.42 kg, dan rata rata : 2.27 kg.
# - Conclution pertanyaan 3 :</br>
#   dilihat dari tabel tertampil maka panjang produk terendah yaitu 7 cm dan tertinggi 105 cm, kemudian ditemukan rata-rata panjang produknya adalah 30,85 cm.
# - Conclution pertanyaan 4 :</br>
#   Berdasarkan tabel dapat kita ketahui bahwa produk yang paling lebar adalah: utilidades_domesticas dengan lebar 118.0 cm. Sedangkan produk yang   memiliki lebar paling kecil adalah: agro_industria_e_comercio dengan lebar 6.0 cm. Adapun rata-rata lebar produk adalah 23.208596165739024 cm.
# - Conclution pertanyaan 5 :</br>
#   jika berdasarkan tabel,kebanyakan produk memiliki 50 sampai 60 karakter dalam penamaannya dengan 76 karekter merupakan penamaan paling panjang dan 5 karakter
#   merupakan penamaan paling pendek,dan jika di rata-rata kan maka mendapatkan hasil 47 karakter.
